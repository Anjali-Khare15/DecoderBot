# %%
import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/angel/Downloads/Task 16-German Credit Scoring Data.csv")

# %%
df
# Out:
#     checking_acc_status  duration                     cred_hist  \
# 0               below_0         6  risky_acc_or_curr_loan_other
# 1             below_200        48          curr_loans_paid_duly
# 2        no_cheking_acc        12  risky_acc_or_curr_loan_other
# 3               below_0        42          curr_loans_paid_duly
# 4               below_0        24                 delay_in_past
# ..                  ...       ...                           ...
# 995      no_cheking_acc        12          curr_loans_paid_duly
# 996             below_0        30          curr_loans_paid_duly
# 997      no_cheking_acc        12          curr_loans_paid_duly
# 998             below_0        45          curr_loans_paid_duly
# 999           below_200        45  risky_acc_or_curr_loan_other
#
#                  purpose  loan_amt       saving_acc_bonds  \
# 0               radio_tv      1169  unknown_no_saving_acc
# 1               radio_tv      5951              below_100
# ...

# %%
plt.scatter(df['loan_amt'],df["age"])
plt.figure()

# %%
sns.pairplot(df)

# %%
plt.scatter(df['loan_amt'],df['duration'])
plt.figure()

# %%
plt.scatter(df['saving_acc_bonds'],df["duration"])
plt.figure()

# %%
fig = df["purpose"].hist(bins=8)
fig.text(-1, 150, 'Frequency', ha='center')
fig.text(0, -30, 'Radio', ha='center')
fig.text(1, -50, 'education', ha='center')
fig.text(2, -30, 'furniture', ha='center')
fig.text(3, -50, 'car', ha='center')
fig.text(4, -30, 'business', ha='center')
fig.text(5, -50, 'appliances', ha='center')
fig.text(6, -30, 'repairs', ha='center')
fig.text(7, -50, 'vacation', ha='center')
# Out:
# Text(7, -50, 'vacation')

# %%
limitedCredit = df[(df["loan_amt"]<=5000)==True];
imitedCredit = df[(df["loan_amt"]>2000)==True];
fig = limitedCredit["purpose"].hist(bins=8)
fig.text(-1, 150, 'Frequency', ha='center')
fig.text(0, -30, 'Radio', ha='center')
fig.text(1, -50, 'education', ha='center')
fig.text(2, -30, 'furniture', ha='center')
fig.text(3, -50, 'car', ha='center')
fig.text(4, -30, 'business', ha='center')
fig.text(5, -50, 'appliances', ha='center')
fig.text(6, -30, 'repairs', ha='center')
fig.text(7, -50, 'vacation', ha='center')
# Out:
# Text(7, -50, 'vacation')

# %%
fig = df.age.hist(bins=60)
fig.text(40, -10, 'Age', ha='center')
fig.text(0, 40, 'Frequency', ha='center')
# Out:
# Text(0, 40, 'Frequency')

# %%
fig = df["job"].hist()
fig.text(-0.5, 400, 'Frequency', ha='center')
fig.text(0, -100, 'UnSkilled', ha='center')
fig.text(1, -100, 'UnSkilled Resident', ha='center')
fig.text(2, -100, 'Skilled', ha='center')
fig.text(3, -100, 'Highly Skilled', ha='center')
# Out:
# Text(3, -100, 'Highly Skilled')

# %% [markdown]
# # Result:
# 1. People from Age 23 to 32 are the target customer and the amount can be in range 2000 to 5000 <currency>.
# 2. Offers for car loan and radio loan can pick up more customers or lenders.
# 3. Short term credit with credit range 2000 t0 5000 yield maximum customer and profits.
